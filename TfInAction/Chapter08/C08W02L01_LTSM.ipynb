# %%
import tensorflow as tf
# Out:
# E:\Anaconda3\tensorflow\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
batch_size = 4
# 3 * 4 * 6
input = tf.random_normal(shape=[3, batch_size, 6], dtype=tf.float32)  
cell = tf.nn.rnn_cell.BasicLSTMCell(10, forget_bias=1.0, state_is_tuple=True)  
init_state = cell.zero_state(batch_size, dtype=tf.float32)  
output, final_state = tf.nn.dynamic_rnn(cell, input, initial_state=init_state, time_major=True) 
#time_major如果是True，就表示RNN的steps用第一个维度表示，建议用这个，运行速度快一点。

# %%
#final_state就是整个LSTM输出的最终的状态，包含c和h。c和h的维度都是[batch_size， n_hidden]  
with tf.Session() as sess:  
    sess.run(tf.global_variables_initializer())  
    print(sess.run(output))  
    print(sess.run(final_state))
# Out:
# [[[-0.19057505 -0.15035677 -0.06921779  0.05903781 -0.03438489
#     0.32301104  0.08231945  0.08338348 -0.05456563 -0.01308341]
#   [-0.05144653  0.07530324  0.0018088  -0.03089219 -0.04843441
#    -0.04360803 -0.12210609  0.08899132 -0.06906492  0.08556893]
#   [-0.01662214  0.04871705  0.02727208 -0.0133822  -0.0420376
#    -0.08019274 -0.05682384  0.00104759  0.06303046  0.04426277]
#   [-0.04487013  0.04056953 -0.09326632  0.0986428   0.04952178
#    -0.02219618 -0.00926131  0.0469741  -0.00916153  0.04560171]]
#
#  [[-0.01511038 -0.00183448  0.09961753 -0.05941795  0.00588005
#     0.03932407 -0.04854523  0.04969102 -0.02887131  0.02827358]
#   [-0.19943492  0.05081494  0.00287472  0.00371953 -0.04910298
#     0.10399505 -0.12077436  0.09360582 -0.14136782  0.09551064]
#   [ 0.01258849  0.07745405  0.0751288   0.017605    0.10408221
#    -0.12036812 -0.03114111 -0.16844411  0.19258331  0.02975713]
#   [ 0.03363911  0.07293037  0.08509696  0.0591954   0.07781351
#    -0.15568452 -0.05544038 -0.1758163   0.00965407  0.06770189]]
#
#  [[ 0.09484248 -0.07017781  0.12984243  0.03295566  0.0598759
#    -0.02612575  0.03075972 -0.03504828  0.03420655 -0.01121735]
#   [-0.07965275  0.1666144   0.07596997  0.02400191 -0.05218421
#    -0.0688194  -0.2415968   0.11015227 -0.13525897  0.15855706]
#   [ 0.10089315 -0.14155316 -0.08419524  0.19902863 -0.04863856
#    -0.00984705  0.07915772  0.09031888  0.11822777 -0.01702046]
#   [-0.06644473  0.1327197   0.20997146  0.01654527  0.05463799
#    -0.16924132 -0.28944337 -0.17380378 -0.1781002   0.30866963]]]
# LSTMStateTuple(c=array([[ 0.3815211 , -0.62505424, -0.17243893, -0.2826894 ,  0.32997298,
#          0.41384655,  0.5593965 , -0.24486765,  0.80122185, -0.59538895],
#        [-0.12032201,  0.19095157,  0.10094714,  0.08583479, -0.11175433,
#         -0.263353  , -0.3487211 ,  0.11036683, -0.08561891,  0.20189019],
#        [ 0.01746712,  0.39002174,  0.1680361 , -0.43712637, -0.04775413,
#         -0.33381623, -0.540897  , -0.01754464, -0.15652832,  0.1307735 ],
#        [ 0.05723585, -0.06961294, -0.07439436, -0.01383638, -0.06029049,
#         -0.39244807, -0.09692622,  0.15676916,  0.51972836,  0.10675712]],
#       dtype=float32), h=array([[ 0.21617897, -0.4080366 , -0.08207136, -0.10094906,  0.21189733,
#          0.19775407,  0.23428977, -0.12725331,  0.19536348, -0.25376922],
#        [-0.06170421,  0.11065719,  0.04462524,  0.04007531, -0.05931513,
#         -0.13435955, -0.19583435,  0.05691195, -0.0425109 ,  0.11005006],
#        [ 0.00637367,  0.15188506,  0.07695515, -0.22289003, -0.02168109,
#         -0.11655806, -0.2591351 , -0.00919532, -0.09820018,  0.06692674],
#        [ 0.0311761 , -0.02329595, -0.04847911, -0.00614315, -0.02985482,
#         -0.27886537, -0.05144921,  0.09115035,  0.3117211 ,  0.04553318]],
#       dtype=float32))
