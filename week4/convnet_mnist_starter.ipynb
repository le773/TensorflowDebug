# %%
# 声明库依赖
import pickle
import numpy as np
import tensorflow as tf
import os
import time

image_size = 28
num_labels = 10

class NotMNIST:
    def __init__(self):
        class Train:
            def __init__(self):
                self.images = []
                self.labels = []
                self.batch_counter = 0

            @property
            def num_examples(self):
                return len(self.images)

            def next_batch(self, num):
                if self.batch_counter + num >= len(self.labels):
                    batch_images = self.images[self.batch_counter:]
                    batch_labels = self.labels[self.batch_counter:]
                    left = num - len(batch_labels)
                    self.batch_counter = left
                else:
                    batch_images = self.images[self.batch_counter:self.batch_counter + num]
                    batch_labels = self.labels[self.batch_counter:self.batch_counter + num]
                    self.batch_counter += num
                return batch_images, batch_labels

        class Test:
            def __init__(self):
                self.images = []
                self.labels = []

        self.train = Train()
        self.test = Test()

        pickle_file = os.getcwd() + '/../data/notMNIST.pickle'

        with open(pickle_file, 'rb') as f:
            save = pickle.load(f)
            train_dataset = save['train_dataset']
            train_labels = save['train_labels']
            valid_dataset = save['valid_dataset']
            valid_labels = save['valid_labels']
            test_dataset = save['test_dataset']
            test_labels = save['test_labels']
            del save  # 删除内存文件，等待gc回收释放内存

        def reformat(dataset, labels):
            dataset = dataset.reshape((-1, image_size * image_size)).astype(np.float32)
            labels = (np.arange(num_labels) == labels[:, None]).astype(np.float32)
            return dataset, labels

        train_dataset, train_labels = reformat(train_dataset, train_labels)
        valid_dataset, valid_labels = reformat(valid_dataset, valid_labels)
        test_dataset, test_labels = reformat(test_dataset, test_labels)
        print('Training set', train_dataset.shape, train_labels.shape)
        print('Validation set', valid_dataset.shape, valid_labels.shape)
        print('Test set', test_dataset.shape, test_labels.shape)
        self.train.images = train_dataset
        self.train.labels = train_labels
        self.test.images = test_dataset
        self.test.labels = test_labels
# Out:
# E:\Anaconda3\tensorflow\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
# %matplotlib inline
""" Using convolutional net on MNIST dataset of handwritten digit
(http://yann.lecun.com/exdb/mnist/)
"""
from __future__ import print_function
from tensorflow.examples.tutorials.mnist import input_data

# %%
# Step 1: Read in data
# using TF Learn's built in function to load MNIST data to the folder data/mnist
# mnist = input_data.read_data_sets("./MNIST_data", one_hot=True)
mnist = NotMNIST()
# Out:
# Training set (200000, 784) (200000, 10)
# Validation set (10000, 784) (10000, 10)
# Test set (10000, 784) (10000, 10)

# %%
# Step 2: Define paramaters for the model
N_CLASSES = 10
LEARNING_RATE = 0.001
BATCH_SIZE = 128
SKIP_STEP = 10
DROPOUT = 0.75
N_EPOCHS = 50

# %%
# Step 3: create placeholders for features and labels
# each image in the MNIST data is of shape 28*28 = 784
# therefore, each image is represented with a 1x784 tensor
# We'll be doing dropout for hidden layer so we'll need a placeholder
# for the dropout probability too
# Use None for shape so we can change the batch_size once we've built the graph
with tf.name_scope('data'):
    X = tf.placeholder(tf.float32, [None, 784], name="X_placeholder")
    Y = tf.placeholder(tf.float32, [None, 10], name="Y_placeholder")

dropout = tf.placeholder(tf.float32, name='dropout')

# %%
# Step 4 + 5: create weights + do inference
# the model is conv -> relu -> pool -> conv -> relu -> pool -> fully connected -> softmax
global_step = tf.Variable(0, dtype=tf.int32, trainable=False, name='global_step')

with tf.variable_scope('conv1') as scope:
    # first, reshape the image to [BATCH_SIZE, 28, 28, 1] to make it work with tf.nn.conv2d
    # use the dynamic dimension -1
    images = tf.reshape(X, shape=[-1, 28, 28, 1])
    # TO DO
    # create kernel variable of dimension [5, 5, 1, 32]
    # use tf.truncated_normal_initializer()

    kernel = tf.get_variable('kernel', [5, 5, 1, 32], initializer=tf.truncated_normal_initializer())
    # TO DO

    # create biases variable of dimension [32]
    biases = tf.get_variable('biases', [32], initializer=tf.random_normal_initializer())
    # use tf.random_normal_initializer()
    # TO DO

    # apply tf.nn.conv2d. strides [1, 1, 1, 1], padding is 'SAME'
    conv = tf.nn.conv2d(images, kernel, strides=[1, 1, 1, 1], padding='SAME')
    # TO DO

    conv1 = tf.nn.relu(conv + biases, name=scope.name)
    # apply relu on the sum of convolution output and biases
    # TO DO
    # output is of dimension BATCH_SIZE x 28 x 28 x 32

# %%
with tf.variable_scope('pool1') as scope:
    # apply max pool with ksize [1, 2, 2, 1], and strides [1, 2, 2, 1], padding 'SAME'
    
    # TO DO
    pool1 = tf.nn.max_pool(conv1, ksize=[1, 2 ,2, 1], strides = [1, 2, 2, 1], padding='SAME')

    # output is of dimension BATCH_SIZE x 14 x 14 x 32

# %%
with tf.variable_scope('conv2') as scope:
    # similar to conv1, except kernel now is of the size 5 x 5 x 32 x 64
    kernel = tf.get_variable('kernels', [5, 5, 32, 64], 
                        initializer=tf.truncated_normal_initializer())
    biases = tf.get_variable('biases', [64],
                        initializer=tf.random_normal_initializer())
    conv = tf.nn.conv2d(pool1, kernel, strides=[1, 1, 1, 1], padding='SAME')
    conv2 = tf.nn.relu(conv + biases, name=scope.name)
    # output is of dimension BATCH_SIZE x 14 x 14 x 64

# %%
with tf.variable_scope('pool2') as scope:
    # similar to pool1
    pool2 = tf.nn.max_pool(conv2, ksize=[1, 2, 2, 1], strides=[1, 2, 2, 1],
                            padding='SAME')

    # output is of dimension BATCH_SIZE x 7 x 7 x 64

# %%
with tf.variable_scope('fc') as scope:
    # use weight of dimension 7 * 7 * 64 x 1024
    input_features = 7 * 7 * 64
    
    # create weights and biases

    w = tf.get_variable('weights',[input_features, 1024], initializer=tf.truncated_normal_initializer())
    b = tf.get_variable('biases', [1024], initializer=tf.random_normal_initializer())
    # TO DO

    # reshape pool2 to 2 dimensional
    pool2 = tf.reshape(pool2, [-1, input_features])

    # apply relu on matmul of pool2 and w + b
    
    # TO DO
    fc = tf.nn.relu(tf.matmul(pool2, w) + b)

    # apply dropout
    fc = tf.nn.dropout(fc, dropout, name='relu_dropout')

# %%
with tf.variable_scope('softmax_linear') as scope:
    # this you should know. get logits without softmax
    # you need to create weights and biases
    w = tf.get_variable('weights', [1024, N_CLASSES], initializer = tf.truncated_normal_initializer())
    b = tf.get_variable('biases', [N_CLASSES], initializer = tf.random_normal_initializer())
    logits = tf.matmul(fc, w) + b
    # TO DO

# %%
# Step 6: define loss function
# use softmax cross entropy with logits as the loss function
# compute mean cross entropy, softmax is applied internally
with tf.name_scope('loss'):
    # you should know how to do this too
    entropy = tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=Y)
    loss = tf.reduce_mean(entropy, name='loss')
    # TO DO
# Out:
# WARNING:tensorflow:From <ipython-input-12-7ee74608f2f5>:6: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See @{tf.nn.softmax_cross_entropy_with_logits_v2}.

# %%
# Step 7: define training op
# using gradient descent with learning rate of LEARNING_RATE to minimize cost
# don't forgot to pass in global_step
# TO DO

optimizer = tf.train.AdadeltaOptimizer(LEARNING_RATE).minimize(loss, global_step=global_step)

with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    saver = tf.train.Saver()
    # to visualize using TensorBoard
    writer = tf.summary.FileWriter(os.getcwd() + '/my_graph/mnist', sess.graph)
    ##### You have to create folders to store checkpoints
    ckpt = tf.train.get_checkpoint_state(os.path.dirname(os.getcwd() + '/checkpoints/convnet_mnist/checkpoint'))
    # if that checkpoint exists, restore from checkpoint
    if ckpt and ckpt.model_checkpoint_path:
        saver.restore(sess, ckpt.model_checkpoint_path)
    
    initial_step = global_step.eval()
    print('initial_step:',initial_step)

    start_time = time.time()
    n_batches = int(mnist.train.num_examples / BATCH_SIZE)

    total_loss = 0.0
    for index in range(initial_step, n_batches * N_EPOCHS): # train the model n_epochs times
        X_batch, Y_batch = mnist.train.next_batch(BATCH_SIZE)
        _, loss_batch = sess.run([optimizer, loss], 
                                feed_dict={X: X_batch, Y:Y_batch, dropout: DROPOUT}) 
        total_loss += loss_batch
        if (index + 1) % SKIP_STEP == 0:
            print('Average loss at step {}: {:5.1f}'.format(index + 1, total_loss / SKIP_STEP))
            total_loss = 0.0
            saver.save(sess, os.getcwd() + '/checkpoints/convnet_mnist/mnist-convnet', index)
    
    print("Optimization Finished!") # should be around 0.35 after 25 epochs
    print("Total time: {0} seconds".format(time.time() - start_time))


    # test the model
    n_batches = int(mnist.test.num_examples/BATCH_SIZE)
    total_correct_preds = 0
    for i in range(n_batches):
        X_batch, Y_batch = mnist.test.next_batch(BATCH_SIZE)
        _, loss_batch, logits_batch = sess.run([optimizer, loss, logits], 
                                        feed_dict={X: X_batch, Y:Y_batch, dropout: DROPOUT}) 
        preds = tf.nn.softmax(logits_batch)
        correct_preds = tf.equal(tf.argmax(preds, 1), tf.argmax(Y_batch, 1))
        accuracy = tf.reduce_sum(tf.cast(correct_preds, tf.float32))
        total_correct_preds += sess.run(accuracy)   
    
    print("Accuracy {0}".format(total_correct_preds/mnist.test.num_examples))
# Out:
# INFO:tensorflow:Restoring parameters from E:\OctaveProject\TensorflowDebug\week4/checkpoints/convnet_mnist/mnist-convnet-3719
# Average loss at step 3730: 50570.6
# Average loss at step 3740: 49784.2
# Average loss at step 3750: 51436.2
# Average loss at step 3760: 51124.6
# Average loss at step 3770: 50482.2
# Average loss at step 3780: 49024.0
# Average loss at step 3790: 49802.7
# Average loss at step 3800: 49581.5
# Average loss at step 3810: 49528.5
# Average loss at step 3820: 50823.0
# Average loss at step 3830: 50173.3
# Average loss at step 3840: 50757.3
# Average loss at step 3850: 49284.0
# Average loss at step 3860: 48095.2
# Average loss at step 3870: 49363.4
# Average loss at step 3880: 48518.5
# Average loss at step 3890: 49138.6
# Average loss at step 3900: 50602.7
# Average loss at step 3910: 49091.3
# Average loss at step 3920: 48995.0
# Average loss at step 3930: 50346.0
# Average loss at step 3940: 48562.6
# Average loss at step 3950: 49904.3
# Average loss at step 3960: 47836.8
# Average loss at step 3970: 48895.0
# Average loss at step 3980: 49863.2
# Average loss at step 3990: 47601.4
# Average loss at step 4000: 47554.8
# Average loss at step 4010: 48446.4
# Average loss at step 4020: 49296.3
# Average loss at step 4030: 48389.6
# Average loss at step 4040: 47633.3
# Average loss at step 4050: 47387.6
# Average loss at step 4060: 48065.5
# Average loss at step 4070: 48521.8
# Average loss at step 4080: 46385.8
# Average loss at step 4090: 46760.7
# Average loss at step 4100: 47796.2
# Average loss at step 4110: 48641.2
# Average loss at step 4120: 48798.6
# Average loss at step 4130: 47806.1
# Average loss at step 4140: 47450.9
# Average loss at step 4150: 48503.3
# Average loss at step 4160: 46464.8
# Average loss at step 4170: 47727.4
# Average loss at step 4180: 49567.2
# Average loss at step 4190: 47510.7
# Average loss at step 4200: 47005.4
# Average loss at step 4210: 48108.5
# Average loss at step 4220: 46817.5
# Average loss at step 4230: 48243.5
# Average loss at step 4240: 48324.7
# Average loss at step 4250: 47371.2
# Average loss at step 4260: 47176.0
# Average loss at step 4270: 48826.8
# Average loss at step 4280: 46755.4
# Average loss at step 4290: 46818.5
# Average loss at step 4300: 47979.2
# Average loss at step 4310: 47783.9
# Average loss at step 4320: 47171.1
# Average loss at step 4330: 45893.2
# Average loss at step 4340: 45464.5
# Average loss at step 4350: 46298.0
# Average loss at step 4360: 46749.5
# Average loss at step 4370: 46328.7
# Average loss at step 4380: 45418.9
# Average loss at step 4390: 47164.6
# Average loss at step 4400: 45900.2
# Average loss at step 4410: 47839.6
# Average loss at step 4420: 45126.4
# Average loss at step 4430: 46485.4
# Average loss at step 4440: 46570.6
# Average loss at step 4450: 46703.5
# Average loss at step 4460: 46821.7
# Average loss at step 4470: 46076.9
# Average loss at step 4480: 45882.0
# Average loss at step 4490: 45208.1
# Average loss at step 4500: 45812.1
# Average loss at step 4510: 45115.9
# Average loss at step 4520: 45151.2
# Average loss at step 4530: 45763.1
# Average loss at step 4540: 44747.1
# Average loss at step 4550: 44558.3
# Average loss at step 4560: 45454.9
# Average loss at step 4570: 46750.6
# Average loss at step 4580: 44998.4
# Average loss at step 4590: 45607.0
# Average loss at step 4600: 45751.7
# Average loss at step 4610: 46617.6
# Average loss at step 4620: 46173.5
# Average loss at step 4630: 46847.9
# Average loss at step 4640: 45195.7
# Average loss at step 4650: 45182.1
# Average loss at step 4660: 45220.3
# Average loss at step 4670: 46365.4
# Average loss at step 4680: 45162.6
# Average loss at step 4690: 46950.0
# Average loss at step 4700: 45175.5
# Average loss at step 4710: 46324.1
# Average loss at step 4720: 44212.1
# Average loss at step 4730: 43999.7
# Average loss at step 4740: 46349.2
# Average loss at step 4750: 44689.2
# Average loss at step 4760: 45586.1
# Average loss at step 4770: 44859.9
# Average loss at step 4780: 44907.1
# Average loss at step 4790: 43602.1
# Average loss at step 4800: 43946.9
# Average loss at step 4810: 45445.1
# Average loss at step 4820: 43348.8
# Average loss at step 4830: 43925.8
# Average loss at step 4840: 44421.4
# Average loss at step 4850: 45374.1
# Average loss at step 4860: 43615.2
# Average loss at step 4870: 43329.6
# Average loss at step 4880: 44844.5
# Average loss at step 4890: 45978.5
# Average loss at step 4900: 44599.0
# Average loss at step 4910: 43686.3
# Average loss at step 4920: 44587.4
# Average loss at step 4930: 42991.3
# Average loss at step 4940: 43978.5
# Average loss at step 4950: 42262.3
# Average loss at step 4960: 44383.4
# Average loss at step 4970: 45247.4
# Average loss at step 4980: 41656.3
# Average loss at step 4990: 43474.7
# Average loss at step 5000: 45346.7
# Average loss at step 5010: 42228.4
# Average loss at step 5020: 42471.4
# Average loss at step 5030: 43162.2
# Average loss at step 5040: 43390.8
# Average loss at step 5050: 45058.6
# Average loss at step 5060: 42143.0
# Average loss at step 5070: 43106.0
# Average loss at step 5080: 42825.9
# Average loss at step 5090: 42905.1
# Average loss at step 5100: 43168.5
# Average loss at step 5110: 42270.6
# Average loss at step 5120: 44226.8
# Average loss at step 5130: 41439.5
# Average loss at step 5140: 43493.1
# Average loss at step 5150: 43969.8
# Average loss at step 5160: 42894.2
# Average loss at step 5170: 42797.0
# Average loss at step 5180: 44085.1
# Average loss at step 5190: 42293.1
# Average loss at step 5200: 43131.7
# Average loss at step 5210: 43422.2
# Average loss at step 5220: 41216.9
# Average loss at step 5230: 40950.8
# Average loss at step 5240: 40797.4
# Average loss at step 5250: 42512.1
# Average loss at step 5260: 42656.9
# Average loss at step 5270: 41853.7
# Average loss at step 5280: 42153.1
# Average loss at step 5290: 41393.1
# Average loss at step 5300: 41826.2
# Average loss at step 5310: 42582.8
# Average loss at step 5320: 42228.8
# Average loss at step 5330: 43096.6
# Average loss at step 5340: 41753.8
# Average loss at step 5350: 40610.6
# Average loss at step 5360: 43411.7
# Average loss at step 5370: 40818.5
# Average loss at step 5380: 42973.0
# Average loss at step 5390: 41096.5
# Average loss at step 5400: 42498.2
# Average loss at step 5410: 41294.3
# Average loss at step 5420: 40795.0
# Average loss at step 5430: 41983.2
# Average loss at step 5440: 40212.5
# Average loss at step 5450: 41415.4
# Average loss at step 5460: 42326.2
# Average loss at step 5470: 40893.4
# Average loss at step 5480: 41095.3
# Average loss at step 5490: 41750.4
# Average loss at step 5500: 41547.5
# Average loss at step 5510: 41152.6
# Average loss at step 5520: 42855.7
# Average loss at step 5530: 42296.0
# Average loss at step 5540: 40074.8
# Average loss at step 5550: 41082.1
# Average loss at step 5560: 40715.2
# Average loss at step 5570: 41012.2
# Average loss at step 5580: 42119.5
# Average loss at step 5590: 40871.3
# Average loss at step 5600: 40747.8
# Average loss at step 5610: 40328.7
# Average loss at step 5620: 41239.8
# Average loss at step 5630: 41074.8
# Average loss at step 5640: 39792.6
# Average loss at step 5650: 40783.2
# Average loss at step 5660: 41013.4
# Average loss at step 5670: 41946.2
# Average loss at step 5680: 40090.8
# Average loss at step 5690: 41015.5
# Average loss at step 5700: 39833.1
# Average loss at step 5710: 39754.0
# Average loss at step 5720: 40102.1
# Average loss at step 5730: 40076.6
# Average loss at step 5740: 40907.2
# Average loss at step 5750: 40461.9
# Average loss at step 5760: 41476.0
# Average loss at step 5770: 39442.4
# Average loss at step 5780: 40434.6
# Average loss at step 5790: 40040.6
# Average loss at step 5800: 39550.7
# Average loss at step 5810: 39207.6
# Average loss at step 5820: 40980.5
# Average loss at step 5830: 41562.9
# Average loss at step 5840: 39601.2
# Average loss at step 5850: 39776.9
# Average loss at step 5860: 39483.8
# Average loss at step 5870: 40530.8
# Average loss at step 5880: 39642.9
# Average loss at step 5890: 39340.7
# Average loss at step 5900: 39095.5
# Average loss at step 5910: 38550.2
# Average loss at step 5920: 39402.7
# Average loss at step 5930: 39422.2
# Average loss at step 5940: 38917.7
# Average loss at step 5950: 40367.1
# Average loss at step 5960: 39224.8
# Average loss at step 5970: 40101.8
# Average loss at step 5980: 39366.5
# Average loss at step 5990: 39448.2
# Average loss at step 6000: 40574.5
# Average loss at step 6010: 39809.1
# Average loss at step 6020: 40001.5
# Average loss at step 6030: 39827.2
# Average loss at step 6040: 39674.6
# Average loss at step 6050: 38275.3
# Average loss at step 6060: 39261.6
# Average loss at step 6070: 39054.4
# Average loss at step 6080: 39016.0
# Average loss at step 6090: 37719.7
# Average loss at step 6100: 38558.9
# Average loss at step 6110: 37820.8
# Average loss at step 6120: 40988.9
# Average loss at step 6130: 37850.2
# Average loss at step 6140: 39559.7
# Average loss at step 6150: 38900.3
# Average loss at step 6160: 38705.3
# Average loss at step 6170: 39833.9
# Average loss at step 6180: 39172.1
# Average loss at step 6190: 39604.3
# Average loss at step 6200: 38492.0
# Average loss at step 6210: 37638.0
# Average loss at step 6220: 38994.4
# Average loss at step 6230: 38668.5
# Average loss at step 6240: 39217.0
# Average loss at step 6250: 38310.5
# Average loss at step 6260: 39383.1
# Average loss at step 6270: 41036.7
# Average loss at step 6280: 38282.2
# Average loss at step 6290: 39906.3
# Average loss at step 6300: 38525.7
# Average loss at step 6310: 39285.1
# Average loss at step 6320: 37988.8
# Average loss at step 6330: 39187.9
# Average loss at step 6340: 39536.2
# Average loss at step 6350: 36844.5
# Average loss at step 6360: 38561.3
# Average loss at step 6370: 38885.4
# Average loss at step 6380: 36952.8
# Average loss at step 6390: 37281.3
# Average loss at step 6400: 38696.3
# Average loss at step 6410: 38627.8
# Average loss at step 6420: 37281.7
# Average loss at step 6430: 37796.7
# Average loss at step 6440: 38042.5
# Average loss at step 6450: 38686.4
# Average loss at step 6460: 36942.0
# Average loss at step 6470: 37782.7
# Average loss at step 6480: 37776.7
# Average loss at step 6490: 38666.5
# Average loss at step 6500: 38762.5
# Average loss at step 6510: 36255.1
# Average loss at step 6520: 38073.6
# Average loss at step 6530: 39287.0
# Average loss at step 6540: 36535.5
# Average loss at step 6550: 36737.1
# Average loss at step 6560: 38257.2
# Average loss at step 6570: 38388.0
# Average loss at step 6580: 37460.3
# Average loss at step 6590: 38649.3
# Average loss at step 6600: 38025.9
# Average loss at step 6610: 37986.3
# Average loss at step 6620: 36605.7
# Average loss at step 6630: 38243.7
# Average loss at step 6640: 37451.6
# Average loss at step 6650: 36520.6
# Average loss at step 6660: 38211.2
# Average loss at step 6670: 36052.2
# Average loss at step 6680: 36620.6
# Average loss at step 6690: 38519.5
# Average loss at step 6700: 36307.1
# Average loss at step 6710: 38343.6
# Average loss at step 6720: 36520.2
# Average loss at step 6730: 37235.3
# Average loss at step 6740: 38727.8
# Average loss at step 6750: 36904.5
# Average loss at step 6760: 36989.7
# Average loss at step 6770: 36342.2
# Average loss at step 6780: 37020.8
# Average loss at step 6790: 36333.9
# Average loss at step 6800: 37279.1
# Average loss at step 6810: 37696.0
# Average loss at step 6820: 36459.4
# Average loss at step 6830: 36542.2
# Average loss at step 6840: 36892.0
# Average loss at step 6850: 36398.6
# Average loss at step 6860: 37298.0
# Average loss at step 6870: 37370.6
# Average loss at step 6880: 36099.3
# Average loss at step 6890: 35129.7
# Average loss at step 6900: 38290.6
# Average loss at step 6910: 35747.9
# Average loss at step 6920: 37291.7
# Average loss at step 6930: 36244.7
# Average loss at step 6940: 36171.2
# Average loss at step 6950: 36587.8
# Average loss at step 6960: 36530.8
# Average loss at step 6970: 35169.5
# Average loss at step 6980: 36288.2
# Average loss at step 6990: 35939.1
# Average loss at step 7000: 36196.4
# Average loss at step 7010: 36092.5
# Average loss at step 7020: 36364.3
# Average loss at step 7030: 36129.4
# Average loss at step 7040: 36621.0
# Average loss at step 7050: 36383.6
# Average loss at step 7060: 36024.0
# Average loss at step 7070: 35570.0
# Average loss at step 7080: 36324.0
# Average loss at step 7090: 36472.9
# Average loss at step 7100: 36485.5
# Average loss at step 7110: 36765.2
# Average loss at step 7120: 36203.6
# Average loss at step 7130: 36763.5
# Average loss at step 7140: 35789.9
# Average loss at step 7150: 36288.5
# Average loss at step 7160: 35655.0
# Average loss at step 7170: 36229.0
# Average loss at step 7180: 35739.8
# Average loss at step 7190: 34865.1
# Average loss at step 7200: 35993.6
# Average loss at step 7210: 36491.5
# Average loss at step 7220: 36127.9
# Average loss at step 7230: 36251.4
# Average loss at step 7240: 33818.9
# Average loss at step 7250: 35486.1
# Average loss at step 7260: 35663.7
# Average loss at step 7270: 36559.3
# Average loss at step 7280: 35161.7
# Average loss at step 7290: 35900.8
# Average loss at step 7300: 37148.3
# Average loss at step 7310: 34128.7
# Average loss at step 7320: 36551.0
# Average loss at step 7330: 35571.3
# Average loss at step 7340: 35314.1
# Average loss at step 7350: 36254.9
# Average loss at step 7360: 35763.1
# Average loss at step 7370: 35533.5
# Average loss at step 7380: 35679.3
# Average loss at step 7390: 35053.6
# Average loss at step 7400: 37041.1
# Average loss at step 7410: 34847.5
# Average loss at step 7420: 35071.6
# Average loss at step 7430: 35774.0
# Average loss at step 7440: 36381.1
# Average loss at step 7450: 35609.0
# Average loss at step 7460: 35340.5
# Average loss at step 7470: 35303.3
# Average loss at step 7480: 35071.7
# Average loss at step 7490: 34608.0
# Average loss at step 7500: 34262.8
# Average loss at step 7510: 36001.1
# Average loss at step 7520: 37145.7
# Average loss at step 7530: 35564.8
# Average loss at step 7540: 35081.7
# Average loss at step 7550: 35441.9
# Average loss at step 7560: 35144.5
# Average loss at step 7570: 36291.1
# Average loss at step 7580: 34671.3
# Average loss at step 7590: 36260.2
# Average loss at step 7600: 35998.2
# Average loss at step 7610: 34255.4
# Average loss at step 7620: 34894.6
# Average loss at step 7630: 33630.2
# Average loss at step 7640: 34103.5
# Average loss at step 7650: 35073.5
# Average loss at step 7660: 32961.0
# Average loss at step 7670: 33653.4
# Average loss at step 7680: 34769.7
# Average loss at step 7690: 35330.6
# Average loss at step 7700: 35214.4
# Average loss at step 7710: 35027.8
# Average loss at step 7720: 35108.5
# Average loss at step 7730: 34798.5
# Average loss at step 7740: 34046.2
# Average loss at step 7750: 34765.7
# Average loss at step 7760: 34451.2
# Average loss at step 7770: 34187.9
# Average loss at step 7780: 34989.5
# Average loss at step 7790: 34811.6
# Average loss at step 7800: 34319.3
# Average loss at step 7810: 34486.2
# Average loss at step 7820: 35712.9
# Average loss at step 7830: 34559.7
# Average loss at step 7840: 35415.4
# Average loss at step 7850: 34890.0
# Average loss at step 7860: 35183.1
# Average loss at step 7870: 34297.1
# Average loss at step 7880: 34772.2
# Average loss at step 7890: 33943.7
# Average loss at step 7900: 34989.7
# Average loss at step 7910: 33802.8
# Average loss at step 7920: 33076.5
# Average loss at step 7930: 35574.7
# Average loss at step 7940: 33782.0
# Average loss at step 7950: 33342.6
# Average loss at step 7960: 34853.4
# Average loss at step 7970: 34662.8
# Average loss at step 7980: 34497.7
# Average loss at step 7990: 34204.9
# Average loss at step 8000: 34126.5
# Average loss at step 8010: 35024.1
# Average loss at step 8020: 32630.3
# Average loss at step 8030: 33616.1
# Average loss at step 8040: 33848.0
# Average loss at step 8050: 34552.4
# Average loss at step 8060: 35218.3
# Average loss at step 8070: 33820.7
# Average loss at step 8080: 34178.4
# Average loss at step 8090: 33617.9
# Average loss at step 8100: 33708.9
# Average loss at step 8110: 34065.2
# Average loss at step 8120: 33805.4
# Average loss at step 8130: 35398.7
# Average loss at step 8140: 34050.8
# Average loss at step 8150: 33286.1
# Average loss at step 8160: 32453.8
# Average loss at step 8170: 34159.2
# Average loss at step 8180: 33840.9
# Average loss at step 8190: 35017.1
# Average loss at step 8200: 34093.0
# Average loss at step 8210: 33043.3
# Average loss at step 8220: 34826.7
# Average loss at step 8230: 34033.2
# Average loss at step 8240: 33386.1
# Average loss at step 8250: 33922.2
# Average loss at step 8260: 33461.5
# Average loss at step 8270: 34509.6
# Average loss at step 8280: 33776.1
# Average loss at step 8290: 33359.9
# Average loss at step 8300: 32674.0
# Average loss at step 8310: 34338.8
# Average loss at step 8320: 33175.4
