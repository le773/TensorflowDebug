# %%
'''
A Recurrent Neural Network (LSTM) implementation example using TensorFlow library.
This example is using the MNIST database of handwritten digits (http://yann.lecun.com/exdb/mnist/)
Long Short Term Memory paper: http://deeplearning.cs.cmu.edu/pdfs/Hochreiter97_lstm.pdf

Author: Aymeric Damien
Project: https://github.com/aymericdamien/TensorFlow-Examples/
'''

from __future__ import print_function

import tensorflow as tf
from tensorflow.contrib import rnn

# Import MNIST data
from tensorflow.examples.tutorials.mnist import input_data
mnist = input_data.read_data_sets("../../../data/mnsit", one_hot=True)
# Out:
# E:\Anaconda3\tensorflow\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# WARNING:tensorflow:From <ipython-input-1-eb7b54b76de5>:17: read_data_sets (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.
# WARNING:tensorflow:From E:\Anaconda3\tensorflow\lib\site-packages\tensorflow\contrib\learn\python\learn\datasets\mnist.py:260: maybe_download (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please write your own downloading logic.
# WARNING:tensorflow:From E:\Anaconda3\tensorflow\lib\site-packages\tensorflow\contrib\learn\python\learn\datasets\mnist.py:262: extract_images (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting /tmp/data/train-images-idx3-ubyte.gz
# WARNING:tensorflow:From E:\Anaconda3\tensorflow\lib\site-packages\tensorflow\contrib\learn\python\learn\datasets\mnist.py:267: extract_labels (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting /tmp/data/train-labels-idx1-ubyte.gz
# WARNING:tensorflow:From E:\Anaconda3\tensorflow\lib\site-packages\tensorflow\contrib\learn\python\learn\datasets\mnist.py:110: dense_to_one_hot (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.one_hot on tensors.
# Extracting /tmp/data/t10k-images-idx3-ubyte.gz
# Extracting /tmp/data/t10k-labels-idx1-ubyte.gz
# WARNING:tensorflow:From E:\Anaconda3\tensorflow\lib\site-packages\tensorflow\contrib\learn\python\learn\datasets\mnist.py:290: DataSet.__init__ (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.

# %%
'''
To classify images using a recurrent neural network, we consider every image
row as a sequence of pixels. Because MNIST image shape is 28*28px, we will then
handle 28 sequences of 28 steps for every sample.
'''

# Parameters
learning_rate = 0.001
training_iters = 100000
batch_size = 128
display_step = 10

# Network Parameters
n_input = 28 # MNIST data input (img shape: 28*28)
n_steps = 28 # timesteps
n_hidden = 128 # hidden layer num of features
n_classes = 10 # MNIST total classes (0-9 digits)

# tf Graph input
x = tf.placeholder("float", [None, n_steps, n_input])
y = tf.placeholder("float", [None, n_classes])

# Define weights
weights = {
    'out': tf.Variable(tf.random_normal([n_hidden, n_classes]))
}
biases = {
    'out': tf.Variable(tf.random_normal([n_classes]))
}

# %%
def RNN(x, weights, biases):

    # Prepare data shape to match `rnn` function requirements
    # Current data input shape: (batch_size, n_steps, n_input)
    # Required shape: 'n_steps' tensors list of shape (batch_size, n_input)

    # Permuting batch_size and n_steps
    x = tf.transpose(x, [1, 0, 2])
    # Reshaping to (n_steps*batch_size, n_input)
    x = tf.reshape(x, [-1, n_input])
    # Split to get a list of 'n_steps' tensors of shape (batch_size, n_input)
    x = tf.split(x, n_steps, 0)

    # Define a gru cell with tensorflow
    lstm_cell = rnn.GRUCell(n_hidden)

    # Get lstm cell output
    outputs, states = rnn.static_rnn(lstm_cell, x, dtype=tf.float32)

    # Linear activation, using rnn inner loop last output
    return tf.matmul(outputs[-1], weights['out']) + biases['out']

# %%
pred = RNN(x, weights, biases)

# Define loss and optimizer
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=pred, labels=y))
optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate).minimize(cost)

# Evaluate model
correct_pred = tf.equal(tf.argmax(pred,1), tf.argmax(y,1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32))
# Out:
# WARNING:tensorflow:From <ipython-input-4-003210d7428f>:4: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See @{tf.nn.softmax_cross_entropy_with_logits_v2}.

# %%
# Initializing the variables
init = tf.global_variables_initializer()

# Launch the graph
with tf.Session() as sess:
    sess.run(init)
    step = 1
    # Keep training until reach max iterations
    while step * batch_size < training_iters:
        batch_x, batch_y = mnist.train.next_batch(batch_size)
        # Reshape data to get 28 seq of 28 elements
        batch_x = batch_x.reshape((batch_size, n_steps, n_input))
        # Run optimization op (backprop)
        sess.run(optimizer, feed_dict={x: batch_x, y: batch_y})
        if step % display_step == 0:
            # Calculate batch accuracy
            acc = sess.run(accuracy, feed_dict={x: batch_x, y: batch_y})
            # Calculate batch loss
            loss = sess.run(cost, feed_dict={x: batch_x, y: batch_y})
            print("Iter " + str(step*batch_size) + ", Minibatch Loss= " + \
                  "{:.6f}".format(loss) + ", Training Accuracy= " + \
                  "{:.5f}".format(acc))
        step += 1
    print("Optimization Finished!")

    # Calculate accuracy for 128 mnist test images
    test_len = 128
    test_data = mnist.test.images[:test_len].reshape((-1, n_steps, n_input))
    test_label = mnist.test.labels[:test_len]
    print("Testing Accuracy:", \
        sess.run(accuracy, feed_dict={x: test_data, y: test_label}))
# Out:
# Iter 1280, Minibatch Loss= 1.968550, Training Accuracy= 0.32812
# Iter 2560, Minibatch Loss= 1.520814, Training Accuracy= 0.42969
# Iter 3840, Minibatch Loss= 1.333009, Training Accuracy= 0.56250
# Iter 5120, Minibatch Loss= 1.094874, Training Accuracy= 0.60156
# Iter 6400, Minibatch Loss= 1.012681, Training Accuracy= 0.57812
# Iter 7680, Minibatch Loss= 0.805969, Training Accuracy= 0.73438
# Iter 8960, Minibatch Loss= 0.769710, Training Accuracy= 0.76562
# Iter 10240, Minibatch Loss= 0.555026, Training Accuracy= 0.80469
# Iter 11520, Minibatch Loss= 0.544991, Training Accuracy= 0.82812
# Iter 12800, Minibatch Loss= 0.547259, Training Accuracy= 0.82031
# Iter 14080, Minibatch Loss= 0.431942, Training Accuracy= 0.89062
# Iter 15360, Minibatch Loss= 0.282613, Training Accuracy= 0.89844
# Iter 16640, Minibatch Loss= 0.405802, Training Accuracy= 0.87500
# Iter 17920, Minibatch Loss= 0.438014, Training Accuracy= 0.88281
# Iter 19200, Minibatch Loss= 0.336017, Training Accuracy= 0.90625
# Iter 20480, Minibatch Loss= 0.252450, Training Accuracy= 0.92969
# Iter 21760, Minibatch Loss= 0.288889, Training Accuracy= 0.90625
# Iter 23040, Minibatch Loss= 0.251315, Training Accuracy= 0.90625
# Iter 24320, Minibatch Loss= 0.249253, Training Accuracy= 0.90625
# Iter 25600, Minibatch Loss= 0.230731, Training Accuracy= 0.92969
# Iter 26880, Minibatch Loss= 0.212712, Training Accuracy= 0.91406
# Iter 28160, Minibatch Loss= 0.192761, Training Accuracy= 0.93750
# Iter 29440, Minibatch Loss= 0.244663, Training Accuracy= 0.91406
# Iter 30720, Minibatch Loss= 0.174561, Training Accuracy= 0.94531
# Iter 32000, Minibatch Loss= 0.192885, Training Accuracy= 0.91406
# Iter 33280, Minibatch Loss= 0.162763, Training Accuracy= 0.94531
# Iter 34560, Minibatch Loss= 0.165697, Training Accuracy= 0.93750
# Iter 35840, Minibatch Loss= 0.218179, Training Accuracy= 0.92188
# Iter 37120, Minibatch Loss= 0.156355, Training Accuracy= 0.94531
# Iter 38400, Minibatch Loss= 0.131663, Training Accuracy= 0.95312
# Iter 39680, Minibatch Loss= 0.201463, Training Accuracy= 0.92969
# Iter 40960, Minibatch Loss= 0.147482, Training Accuracy= 0.95312
# Iter 42240, Minibatch Loss= 0.153184, Training Accuracy= 0.92969
# Iter 43520, Minibatch Loss= 0.150570, Training Accuracy= 0.95312
# Iter 44800, Minibatch Loss= 0.229444, Training Accuracy= 0.93750
# Iter 46080, Minibatch Loss= 0.164990, Training Accuracy= 0.95312
# Iter 47360, Minibatch Loss= 0.225697, Training Accuracy= 0.92188
# Iter 48640, Minibatch Loss= 0.153854, Training Accuracy= 0.96875
# Iter 49920, Minibatch Loss= 0.112295, Training Accuracy= 0.96875
# Iter 51200, Minibatch Loss= 0.139012, Training Accuracy= 0.96875
# Iter 52480, Minibatch Loss= 0.158427, Training Accuracy= 0.94531
# Iter 53760, Minibatch Loss= 0.135067, Training Accuracy= 0.96875
# Iter 55040, Minibatch Loss= 0.175723, Training Accuracy= 0.93750
# Iter 56320, Minibatch Loss= 0.098060, Training Accuracy= 0.97656
# Iter 57600, Minibatch Loss= 0.105763, Training Accuracy= 0.96094
# Iter 58880, Minibatch Loss= 0.073619, Training Accuracy= 0.98438
# Iter 60160, Minibatch Loss= 0.086240, Training Accuracy= 0.96875
# Iter 61440, Minibatch Loss= 0.215410, Training Accuracy= 0.93750
# Iter 62720, Minibatch Loss= 0.087003, Training Accuracy= 0.95312
# Iter 64000, Minibatch Loss= 0.162468, Training Accuracy= 0.96094
# Iter 65280, Minibatch Loss= 0.166462, Training Accuracy= 0.95312
# Iter 66560, Minibatch Loss= 0.128307, Training Accuracy= 0.96875
# Iter 67840, Minibatch Loss= 0.231413, Training Accuracy= 0.95312
# Iter 69120, Minibatch Loss= 0.120291, Training Accuracy= 0.97656
# Iter 70400, Minibatch Loss= 0.231165, Training Accuracy= 0.92188
# Iter 71680, Minibatch Loss= 0.175733, Training Accuracy= 0.92188
# Iter 72960, Minibatch Loss= 0.089323, Training Accuracy= 0.96875
# Iter 74240, Minibatch Loss= 0.107593, Training Accuracy= 0.97656
# Iter 75520, Minibatch Loss= 0.066679, Training Accuracy= 0.98438
# Iter 76800, Minibatch Loss= 0.095276, Training Accuracy= 0.97656
# Iter 78080, Minibatch Loss= 0.107154, Training Accuracy= 0.98438
# Iter 79360, Minibatch Loss= 0.182273, Training Accuracy= 0.95312
# Iter 80640, Minibatch Loss= 0.067637, Training Accuracy= 0.99219
# Iter 81920, Minibatch Loss= 0.103490, Training Accuracy= 0.95312
# Iter 83200, Minibatch Loss= 0.130507, Training Accuracy= 0.96875
# Iter 84480, Minibatch Loss= 0.050087, Training Accuracy= 0.98438
# Iter 85760, Minibatch Loss= 0.120924, Training Accuracy= 0.97656
# Iter 87040, Minibatch Loss= 0.087635, Training Accuracy= 0.96094
# Iter 88320, Minibatch Loss= 0.040489, Training Accuracy= 0.99219
# Iter 89600, Minibatch Loss= 0.135894, Training Accuracy= 0.97656
# Iter 90880, Minibatch Loss= 0.091920, Training Accuracy= 0.94531
# Iter 92160, Minibatch Loss= 0.063122, Training Accuracy= 0.98438
# Iter 93440, Minibatch Loss= 0.095381, Training Accuracy= 0.96875
# Iter 94720, Minibatch Loss= 0.184649, Training Accuracy= 0.93750
# Iter 96000, Minibatch Loss= 0.090954, Training Accuracy= 0.96094
# Iter 97280, Minibatch Loss= 0.091556, Training Accuracy= 0.96875
# Iter 98560, Minibatch Loss= 0.111345, Training Accuracy= 0.95312
# Iter 99840, Minibatch Loss= 0.074884, Training Accuracy= 0.97656
# Optimization Finished!
# Testing Accuracy: 0.9921875
